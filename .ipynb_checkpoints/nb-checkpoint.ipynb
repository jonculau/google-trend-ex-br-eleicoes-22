# %% [markdown]
# # Google Trends
#
# Google Trends é uma ferramenta do Google que mostra os mais populares termos buscados em um passado recente.
#
# ## Relatório de comparação de tendências

# %%
# %%capture --no-display
import math
from pickletools import uint8
from pytrends.request import TrendReq
from pandas import DataFrame
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import Markdown, display
def plotComparison(dataFrame:DataFrame, cols:uint8, showValues=False, Incerteza=False, ylin=[]):
    plt.figure(figsize=(20,5))
    Patch = []
    if (len(ylin)>0):
        plt.axes().set_ylim(ylin)
    for col in dataFrame.columns[0:cols]:
        color = 'red' if col == dataFrame.columns[0] else 'blue' if col == dataFrame.columns[1] else 'orange'
        Patch.append(mpatches.Patch(color=color, label=col))
        if Incerteza:
            for i in range(len(dataFrame[col])):
                plt.plot(dataFrame[col][i:i+2], label=col, color=color, linewidth=dataFrame['Incerteza'][i]*2, alpha=0.05)
        else:
            plt.plot(dataFrame[col], label=col, color=color)
    plt.legend(handles=Patch)
    if showValues:
        for index, row in dataFrame.iterrows():
            if index.minute == 0 and index.hour == 0 and index.second == 0:
                for col in dataFrame.columns[0:cols]:
                    plt.text(index, row[col], "{:.1f}".format(row[col]))
                


# Palavras-chave
kw_list = ['lula', 'bolsonaro', 'lula bolsonaro']
conn = TrendReq(hl='pt-BR', tz=360, requests_args={'verify':False}) # Conexão com o Google Trends
req = conn.get_historical_interest(kw_list, year_start=2022, month_start=10, day_start=3, hour_start=0, year_end=2022, month_end=10, day_end=30, hour_end=0, geo='BR', gprop='')

# %% [markdown]
# ### Dados Lidos do Google Trends

# %%
display(req)
plotComparison(req, 3)
# Out:
#                      lula  bolsonaro  lula bolsonaro  isPartial
# date
# 2022-10-03 00:00:00    88         86              40      False
# 2022-10-03 01:00:00    89        100              36      False
# 2022-10-03 02:00:00    73         83              27      False
# 2022-10-03 03:00:00    61         66              25      False
# 2022-10-03 04:00:00    67         69              28      False
# ...                   ...        ...             ...        ...
# 2022-10-19 19:00:00    13         12               3      False
# 2022-10-19 20:00:00    15         14               3      False
# 2022-10-19 21:00:00    15         15               4      False
# 2022-10-19 22:00:00    17         21               4      False
# 2022-10-19 23:00:00    16         18               3       True
#
# [410 rows x 4 columns]

# %% [markdown]
# ### Acumulado, crescimento em escala de log

# %%
accum = []
idArr = []
for index,row in req.iterrows():
    total = (math.fsum(row[v] for v in kw_list[0:2]))
    accum.append({})
    idArr.append(index)
    for col in kw_list:
        accum[-1][col] = row[col] + accum[-2][col] if len(accum)>1 else row[col]
dataFrame = DataFrame(accum,index=idArr)
for col in dataFrame.columns[0:len(kw_list)]:
    dataFrame[col] = dataFrame[col].apply(lambda x: math.log(x))
plotComparison(dataFrame, 2)

# %% [markdown]
# ### Embate percentual com incerteza

# %%
accumPercent = []
for x in accum:
    accumPercent.append({})
    total = (math.fsum(x[v] for v in kw_list[0:2]))
    for col in kw_list[0:2]:
        accumPercent[-1][col] = (x[col]/total)*100
    accumPercent[-1]["Incerteza"] = x[kw_list[2]] / (x[kw_list[2]]+total) * 100
dataFrame = DataFrame(accumPercent,index=idArr)
plotComparison(dataFrame, 2, True, True , ylin=[0,100])

# %% [markdown]
# ## Por região

# %%
# %%capture --no-display
dataByRegion = conn.interest_by_region(resolution='COUNTRY')
display(dataByRegion)
# Out:
#                      lula  bolsonaro  lula bolsonaro
# geoName
# Acre                   40         44              16
# Alagoas                42         44              14
# Amapá                  42         45              13
# Amazonas               45         43              12
# Bahia                  43         43              14
# Ceará                  45         42              13
# Distrito Federal       43         46              11
# Espírito Santo         42         44              14
# Goiás                  44         42              14
# Maranhão               43         42              15
# Mato Grosso            41         43              16
# Mato Grosso do Sul     43         43              14
# Minas Gerais           41         45              14
# Paraná                 41         45              14
# Paraíba                44         42              14
# Pará                   43         43              14
# Pernambuco             44         42              14
# Piauí                  42         43              15
# Rio Grande do Norte    43         44              13
# Rio Grande do Sul      44         44              12
# Rio de Janeiro         42         47              11
# Rondônia               41         44              15
# Roraima                43         43              14
# Santa Catarina         44         43              13
# Sergipe                42         44              14
# São Paulo              43         46              11
# Tocantins              42         43              15

# %% [markdown]
# ## Principais Tópicos

# %%
# %%capture --no-display
display(conn.related_queries())
# Out:
# {'lula': {'top':                            query  value
#   0                 lula bolsonaro    100
#   1                      bolsonaro     97
#   2               lula e bolsonaro     44
#   3                    lula debate     34
#   4                   governo lula     27
#   5          debate lula bolsonaro     25
#   6                  pesquisa lula     24
#   7              desmatamento lula     23
#   8                   desmatamento     22
#   9        debate bolsonaro e lula     20
#   10       lula bolsonaro pesquisa     20
#   11       pesquisa lula bolsonaro     19
#   12             lula ou bolsonaro     17
#   13               lula presidente     15
#   14                     lula 2022     14
#   15                     flow lula     13
#   16     desmatamento governo lula     13
#   17     bolsonaro e lula pesquisa     10
#   18                     lula hoje     10
#   19        desmatamento bolsonaro      7
#   20   desmatamento lula bolsonaro      7
#   21                  lula no flow      7
#   22    debate de lula e bolsonaro      7
#   23  desmatamento no governo lula      5
#   24              bolsonaro x lula      5,
#   'rising':                                     query  value
#   0                            lula no flow  60050
#   1                               flow lula  46750
#   2                       podcast flow lula  22600
#   3                       flow podcast lula  21600
#   4                    lula no flow podcast  20950
#   5                        lula transfobico  18950
#   6    quem desmatou mais lula ou bolsonaro  18600
#   7               desmatamento governo lula  14700
#   8                    entrevista lula flow  14250
#   9                       desmatamento lula  12600
#   10                           desmatamento  12050
#   11           desmatamento no governo lula  11250
#   12                 desmatamento bolsonaro  10300
#   13            desmatamento lula bolsonaro  10250
#   14         desmatamento governo bolsonaro   9500
#   15          desmatamento lula x bolsonaro   8550
#   16          desmatamento lula e bolsonaro   8250
#   17      desmatamento no governo bolsonaro   7750
#   18  desmatamento na amazonia governo lula   7150
#   19               desmatamento na amazonia   7100
#   20          desmatamento na amazonia lula   7100
#   21        desmatamento no governo do lula   6900
#   22     desmatamento amazonia governo lula   6900
#   23  desmatamento governo lula e bolsonaro   6450
#   24    desmatamento no brasil governo lula   5900},
#  'bolsonaro': {'top':                          query  value
#   0               bolsonaro lula    100
#   1                         lula     97
#   2             lula e bolsonaro     45
#   3           pesquisa bolsonaro     30
#   4        debate lula bolsonaro     24
#   5      lula e bolsonaro debate     20
#   6      lula bolsonaro pesquisa     19
#   7      debate lula e bolsonaro     19
#   8            lula ou bolsonaro     16
#   9               jair bolsonaro     16
#   10           governo bolsonaro     16
#   11        bolsonaro presidente     16
#   12              bolsonaro 2022     14
#   13                desmatamento     12
#   14      desmatamento bolsonaro     12
#   15             filha bolsonaro     11
#   16              bolsonaro hoje     11
#   17              flow bolsonaro     10
#   18   lula e bolsonaro pesquisa     10
#   19         bolsonaro na frente     10
#   20           desmatamento lula      8
#   21       bolsonaro debate band      7
#   22          michelle bolsonaro      7
#   23          filha de bolsonaro      7
#   24  debate de lula e bolsonaro      7,
#   'rising':                                           query  value
#   0                                barbara gancia  50500
#   1                    jornalista filha bolsonaro  44150
#   2                barbara gancia filha bolsonaro  43650
#   3                   desmatamento jair bolsonaro  24650
#   4                             bolsonaro no flow  23000
#   5          quem desmatou mais lula ou bolsonaro  16200
#   6                                flow bolsonaro  16050
#   7                     jornalista barbara gancia  12200
#   8                             desmatamento lula  11450
#   9                     desmatamento governo lula  10600
#   10          jornalista chama filha de bolsonaro   9650
#   11          jornalista ataca filha de bolsonaro   9400
#   12                desmatamento lula x bolsonaro   9000
#   13                desmatamento lula e bolsonaro   8400
#   14                       bolsonaro flow podcast   7900
#   15                 desmatamento no governo lula   7850
#   16                               barbara garcia   7300
#   17  jornalista chama filha de bolsonaro de puta   7050
#   18                       desmatamento bolsonaro   6950
#   19                                 desmatamento   6850
#   20               desmatamento governo bolsonaro   6850
#   21        desmatamento governo lula e bolsonaro   6750
#   22            desmatamento no governo bolsonaro   5850
#   23        desmatamento governo lula x bolsonaro   5100
#   24                               bárbara gancia   4300},
#  'lula bolsonaro': {'top':                                 query  value
#   0               debate lula bolsonaro    100
#   1             pesquisa lula bolsonaro     81
#   2             debate lula e bolsonaro     81
#   3                       lula pesquisa     79
#   4                  bolsonaro pesquisa     79
#   5             debate bolsonaro e lula     77
#   6                   lula ou bolsonaro     68
#   7           lula e bolsonaro pesquisa     39
#   8                   governo bolsonaro     34
#   9                        governo lula     31
#   10             desmatamento bolsonaro     31
#   11                       desmatamento     29
#   12                  desmatamento lula     29
#   13        desmatamento lula bolsonaro     29
#   14         debate de bolsonaro e lula     28
#   15                          lula hoje     22
#   16                     bolsonaro hoje     21
#   17         debate do lula e bolsonaro     19
#   18       pesquisa de bolsonaro e lula     18
#   19          desmatamento governo lula     16
#   20       debate lula e bolsonaro band     16
#   21     desmatamento governo bolsonaro     15
#   22  pesquisa eleitoral lula bolsonaro     15
#   23         lula ou bolsonaro pesquisa     14
#   24                     jair bolsonaro     14,
#   'rising':                                             query  value
#   0            quem desmatou mais lula ou bolsonaro  25400
#   1                                    lula no flow  20700
#   2                               bolsonaro no flow  17850
#   3                     desmatamento jair bolsonaro  17100
#   4                                       flow lula  16100
#   5                                  flow bolsonaro  12350
#   6                          flow podcast bolsonaro   9650
#   7                               flow podcast lula   9050
#   8                          desmatamento bolsonaro   8500
#   9                                    desmatamento   8050
#   10                    desmatamento lula bolsonaro   7950
#   11                              desmatamento lula   7900
#   12                      desmatamento governo lula   7850
#   13                 desmatamento governo bolsonaro   7700
#   14                  desmatamento lula x bolsonaro   7100
#   15                              chocolates anvisa   7050
#   16                  desmatamento lula e bolsonaro   6700
#   17              desmatamento no governo bolsonaro   6700
#   18              invasão igreja luterana joinville   6300
#   19                   desmatamento no governo lula   6200
#   20  desmatamento governo lula e governo bolsonaro   5800
#   21          desmatamento governo lula e bolsonaro   5750
#   22  desmatamento governo lula x governo bolsonaro   5700
#   23          desmatamento na amazonia governo lula   4700
#   24          desmatamento governo lula x bolsonaro   4700}}
